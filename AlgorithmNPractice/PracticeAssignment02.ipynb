# %% [markdown]
# # 알고리즘 및 실습 실습과제 2 - ()
#
# # [문제 1] 교재 1장 연습문제 55쪽의 문제 24 풀기
#  - [힌트] 영상에 코드와 설명이 모두 나와 있음. 다양한 입력에 대해 테스트하고 소스코드나 보고서에 충분한 설명을 넣을 것
# ## [문제 1, 55P-24] 우선순위 큐를 이용해 숫자를 정렬하는 프로그램을 구현해 보자. 숫자로 이루어진 리스트 를 입력받아 우선순위 큐에 모두 넣은 다음 순서대로 하나씩 꺼내서 원래의 리스트에 저장 하면 정렬할 수 있다. 우선순위 큐로는 파이썬의 heapq 모듈을 사용하라 (8.6절의 허프만 코드에서 heapq의 사용법을 참고하라).

# %%
import heapq

def sortByHeap(target):
    sortedList = []
    heapq.heapify(target)
    # 정렬 대상 리스트를 heapify (힙 구조로 만들기)
    while target:
        sortedList.append(heapq.heappop(target))
        # 가장 작은 원소부터 빼서 새 리스트에 옮겨닮기
    return sortedList

targetList = list(map(int, input().split(' ')))
targetList = sortByHeap(targetList)
print(f'SortedList: {targetList}')
# Out:
# 3 7 2 1 6 5 9
# SortedList: [1, 2, 3, 5, 6, 7, 9]

# %% [markdown]
# ## [문제 2] 교재 2장 연습문제 92쪽의 문제 3 풀기 <코딩 불필요>
#  - 보고서에 충분한 설명을 넣을 것
#
# ### [문제 2, 92P-3] 다음의 두 알고리즘이 입력의 크기에 따라 어떤 증가 속도를 갖는지를 설명하고, 입력의 구성에 따라 처리 시간이 달라지는지를 설명하라.
#
#  - (1) 입력 리스트에서 어떤 항목이 있는지를 검사하는 알고리즘
#
#  - (2) 입력 리스트에서 어떤 항목이 몇 번 나타나는지를 구하는 알고리즘
#
# 두 알고리즘 모두 입력이 증가할 수록 실행 시간도 증가하는 `O(n)`의 시간 복잡도로 선형 시간 복잡도를 가지는 알고리즘이나, (1)의 알고리즘의 경우 주어지는 입력에서 찾을 항목을 찾는 경우 바로 종료되는 반면, (2)의 알고리즘의 경우 주어지는 입력에서 찾을 항목을 찾는 것과 관계없이 모든 입력을 처음부터 끝까지 탐색한다는 점에서 처리 시간이 달라질 수 있다. (통상적으로 (1)의 알고리즘이 (2)의 알고리즘 보다 빠르게 실행 완료될 여지가 있다.)

# %% [markdown]
# ### [문제 3] 교재 2장 연습문제 93쪽의 문제 9를 참고하여 다음을 증명하라.

# %% [markdown]
# 복잡도 함수 f(n) 이 주어졌을 때 n ≥ n0인 모든 정수에 대해 |f(n)| ≤ c|g(n)|을 만족 하는 양의 상수 c와 자연수 n0 가 존재하면 f(n) ∈ O(g(n))) 이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 빅오 표기법의 정의에 따라 해당하는 c와 n0을 찾으면 c=10000, n0=2인 경우 이후의 모든 n>=n0=2에 대해서 |5n^2 + 10000n| <= c |n^2|이 성립한다. 따라서 (1)의 식이 성립한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2n^3 + 3n이 O(n^2)에 포함되는 것을 보이기 위해서는 n>=n0인 모든 n에 대해서 |2n^3 + 3n| <= c|n^2|을 만족하는 c와 n0가 존재해야 한다. 양변을 n^2로 나누면, |2n + 3n^-1| <= c가 되는데 아무리 큰 c를 설정해도 이보다 큰 n이 존재할 수 있기 때문에 (2)의 식은 성립하지 않는다.

# %% [markdown]
# # [문제 4] 교재 연습문제 93쪽의 문제 11 중 3개 이상을 풀고, 12번과 같이 빅오 표기법으로 나타내라.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 주어지는 입력에 상관 없이 항상 결과까지 걸리는 시간이 덧셈 9번으로 동일하므로 상수 시간 복잡도를 가진다.
#
# `O(1)`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 주어지는 입력 n에 따른 덧셈 n번을 수행해야 하므로 선형 시간 복잡도를 가진다.
#
# `O(n)`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 주어지는 입력 n에 따라, n^2번의 덧셈을 수행해야 하므로 이차 다항 시간 복잡도를 가진다.
#
# `O(n^2)`
